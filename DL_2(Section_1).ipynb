# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from gensim.models import Word2Vec
from scipy import spatial
import networkx as nx
import csv

# %%
df = pd.read_csv('/content/medium_articles.csv')
df.head()
# Out:
#                               title  \
# 0               Mental Note Vol. 24
# 1         Your Brain On Coronavirus
# 2                    Mind Your Nose
# 3          The 4 Purposes of Dreams
# 4  Surviving a Rod Through the Head
#
#                                                 text  \
# 0  Photo by Josh Riemer on Unsplash\n\nMerry Chri...
# 1  Your Brain On Coronavirus\n\nA guide to the cu...
# 2  Mind Your Nose\n\nHow smell training can chang...
# 3  Passionate about the synergy between science a...
# 4  You’ve heard of him, haven’t you? Phineas Gage...
#
#                                                  url                 authors  \
# 0  https://medium.com/invisible-illness/mental-no...            ['Ryan Fan']
# 1  https://medium.com/age-of-awareness/how-the-pa...       ['Simon Spichak']
# 2  https://medium.com/neodotlife/mind-your-nose-f...                      []
# 3  https://medium.com/science-for-real/the-4-purp...  ['Eshan Samaranayake']
# 4  https://medium.com/live-your-life-on-purpose/s...        ['Rishav Sinha']
#
#                           timestamp  \
# 0  2020-12-26 03:38:10.479000+00:00
# 1  2020-09-23 22:10:17.126000+00:00
# 2  2020-10-10 20:17:37.132000+00:00
# 3  2020-12-21 16:05:19.524000+00:00
# 4  2020-02-26 00:01:01.576000+00:00
#
#                                                 tags
# 0  ['Mental Health', 'Health', 'Psychology', 'Sci...
# 1  ['Mental Health', 'Coronavirus', 'Science', 'P...
# 2  ['Biotechnology', 'Neuroscience', 'Brain', 'We...
# 3  ['Health', 'Neuroscience', 'Mental Health', 'P...
# 4  ['Brain', 'Health', 'Development', 'Psychology...

# %%
df = df[['title','text']]
df.shape
# Out:
# (192368, 2)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (190827, 2)

# %%
df['text'] = df['text'].str.replace('\n','<|n|>')

# %%
sample_blog = df['text'][10]
print(sample_blog)
# Out:
# Photo credit: Leo Leung<|n|><|n|>People want to know why you do what you do.<|n|><|n|>If you’re an entrepreneur, your investors, customers, and employees want to know why you founded your company. Apply for a job, and recruiters ask about your career path. If you’re a freelancer, everyone is curious about how you got started.<|n|><|n|>Why do we crave origin stories? Because they reveal character. Superman is a good guy because his planet exploded, his parents sent him to Earth, and the Kents raised him to fight evil. Steve Jobs became a trusted CEO, in part, by bouncing back from failure. My dad thrived as a home builder, but only after terminating a partnership with a prominent colleague whose practices he found unethical.<|n|><|n|>In other words:<|n|><|n|>Your origin story helps people decide whether or not to trust you.<|n|><|n|>How to Craft a Powerful Origin Story: The 5 Essential Elements<|n|><|n|>In strategic messaging and positioning engagements with CEOs, as well as business storytelling workshops for teams, I’ve helped hundreds of people construct origin stories. The best instantly convey not only trustworthiness, but also traits like commitment, persistence, and curiosity.<|n|><|n|>So what makes a great origin story work?<|n|><|n|>At the heart of every great origin story is a single event that forever changes the course of the teller’s life. Typically it arises out of failure or disappointment; sometimes it’s an unexpected discovery. Very frequently, another person illuminates a new way forward.<|n|><|n|>Can you pinpoint the event that set you on your current path? (Yes, we all have one.) The event doesn’t have to be life-changing in the “I won the lottery” sense (though congrats if that happened). It just has to reorient you towards what you’re doing now.<|n|><|n|>Once you’ve identified your event, construct your origin story around it using the following five components, and tell it in this order:<|n|><|n|>1. Once upon a time…<|n|><|n|>How was your life before the life-changing event? Most importantly, what did you want back then? Share relevant details: How old were you? Where did you live? When did this happen? (No, you don’t literally have to start with “Once upon a time…”)<|n|><|n|>For example, here’s the “Once upon a time…” for my origin story:<|n|><|n|>Back in the dot-com years, I was living in Manhattan, struggling to fund my startup. It was not going well. One VC attached a hand-written note to his standard rejection letter: “Andy, I rate every business plan I receive on a scale of one to 10. Yours is a one.” At the bottom, he wrote, “P.S. Not a compelling story.”<|n|><|n|>2. “Then one day…”<|n|><|n|>Next, describe your life-changing event. If possible, tell this section as a scene with details that the listener can sense (visualize, hear, smell, etc.). Again, here’s mine:<|n|><|n|>One day, I’m walking up Broadway, when I notice a huge sign in the window of a Barnes and Noble. The sign says, “For anyone who wants to tell a compelling story,” and it’s pointing to a book about screenwriting. I buy the book.<|n|><|n|>3. “Because of that…”<|n|><|n|>What relevant events were then set in motion? What obstacles did you have to overcome? Basically, describe what happened next:<|n|><|n|>That night, I read the book from cover to cover. It’s written in the language of feature films (three act structure, etc.), but much of it seems to apply to telling the story of a startup. I rewrite my pitch and send it to a new batch of investors.<|n|><|n|>4. “Until finally…”<|n|><|n|>What was the turning point — the moment when you really committed to the new path? It’s especially effective to reflect here on how you changed and what you learned:<|n|><|n|>After receiving the revised pitch, several investor groups invite my team to their offices, and four months later we have a term sheet from a prominent Silicon Valley venture firm. The numbers, the team — all remained same. The only thing that changed was how we told our story.<|n ...

# %%
sentences = sent_tokenize(sample_blog)
sentences_clean = [re.sub(r'[^\w\s]','',sentence.lower()) for sentence in sentences]
stop_words = stopwords.words('english')

sentence_tokens = [[words for words in sentence.split(' ') if words not in stop_words] for sentence in sentences_clean]
w2v = Word2Vec(sentence_tokens,vector_size=1, min_count=1, epochs=1000)

sentence_embeddings = [[w2v.wv.get_vector(word)[0] for word in words] for words in sentence_tokens]
max_len = max([len(tokens) for tokens in sentence_tokens])
sentence_embeddings = [np.pad(embedding,(0,max_len-len(embedding)),'constant') for embedding in sentence_embeddings]

# %%
similarity_matrix = np.zeros([len(sentence_tokens), len(sentence_tokens)])
for i, row_embedding in enumerate(sentence_embeddings):
    for j, column_embedding in enumerate(sentence_embeddings):
        similarity_matrix[i][j] = 1 - spatial.distance.cosine(row_embedding, column_embedding)

nx_graph = nx.from_numpy_array(similarity_matrix)
scores = nx.pagerank(nx_graph, max_iter=500)

top_sentence = {sentence: scores[index] for index, sentence in enumerate(sentences)}
sentNeeded = round(0.25 * len(sentences)) - 1
top = dict(sorted(top_sentence.items(), key=lambda x: x[1], reverse=True)[:sentNeeded])

summary = ""
for sent in sentences:
    if sent in top.keys():
        summary += sent
print(summary)
# Out:
# Apply for a job, and recruiters ask about your career path.If you’re a freelancer, everyone is curious about how you got started.<|n|><|n|>Why do we crave origin stories?Steve Jobs became a trusted CEO, in part, by bouncing back from failure.Very frequently, another person illuminates a new way forward.<|n|><|n|>Can you pinpoint the event that set you on your current path?The sign says, “For anyone who wants to tell a compelling story,” and it’s pointing to a book about screenwriting.Basically, describe what happened next:<|n|><|n|>That night, I read the book from cover to cover.It’s written in the language of feature films (three act structure, etc.I rewrite my pitch and send it to a new batch of investors.<|n|><|n|>4.“Until finally…”<|n|><|n|>What was the turning point — the moment when you really committed to the new path?Pay particular attention to where they lean in.<|n|><|n|>Also, ask others to tell you their origin stories.

# %%
count = 0
def generateSummary(blog):
    global count
    count += 1
    print("Summarising blog ", count)
    try:
        sentences = sent_tokenize(blog)
        sentences_clean = [re.sub(r'[^\\w\\s]', '', sentence.lower()) for sentence in sentences]
        stop_words = stopwords.words('english')
        sentence_tokens = [[words for words in sentence.split(' ') if words not in stop_words] for sentence in sentences_clean]
        w2v = Word2Vec(sentence_tokens, vector_size=1, min_count=1, epochs=1000)
        sentence_embeddings = [[w2v.wv.get_vector(word) for word in words] for words in sentence_tokens]
        max_len = max([len(tokens) for tokens in sentence_tokens])
        sentence_embeddings = [np.pad(embedding, (0, max_len-len(embedding)), 'constant') for embedding in sentence_embeddings]
        similarity_matrix = np.zeros([len(sentence_tokens), len(sentence_tokens)])
        for i, row_embedding in enumerate(sentence_embeddings):
            for j, column_embedding in enumerate(sentence_embeddings):
                similarity_matrix[i][j] = 1 - spatial.distance.cosine(row_embedding, column_embedding)
        nx_graph = nx.from_numpy_array(similarity_matrix)
        scores = nx.pagerank(nx_graph, max_iter=600)
        top_sentence = {sentence: scores[index] for index, sentence in enumerate(sentences)}
        sentNeeded = round(0.25 * len(sentences)) - 1
        top = dict(sorted(top_sentence.items(), key=lambda x: x[1], reverse=True)[:sentNeeded])

        summary = ""
        for sent in sentences:
            if sent in top.keys():
                summary += sent
        return summary
    except:
        return float("NaN")

# %%
import csv

filename = "articlesSet.csv"
fields = ['title', 'summary', 'content']

# Writing to CSV file
with open(filename, 'a', newline='', encoding='utf-8') as csvfile:
    # Creating a csv writer object
    csvwriter = csv.writer(csvfile)

    # Write the header if the file is empty
    if csvfile.tell() == 0:
        csvwriter.writerow(fields)

    # Define the callback function to process each row
    def callback(row):
        summary = generateSummary(row['text'])

        # Only proceed if the summary is a valid string
        if isinstance(summary, str):
            rows = [row['title'], summary, row['text']]
            csvwriter.writerow(rows)

    # Apply the callback function to each row in the DataFrame
    df.apply(callback, axis=1)
# Out:
# Summarising blog  1
# Summarising blog  2
# Summarising blog  3
# Summarising blog  4
# Summarising blog  5
# Summarising blog  6
# Summarising blog  7
# Summarising blog  8
# Summarising blog  9
# Summarising blog  10
# Summarising blog  11
# Summarising blog  12
# Summarising blog  13
# Summarising blog  14
# Summarising blog  15
# Summarising blog  16
# Summarising blog  17
# Summarising blog  18
# Summarising blog  19
# Summarising blog  20
# Summarising blog  21
# Summarising blog  22
# Summarising blog  23
# Summarising blog  24
# Summarising blog  25
# Summarising blog  26
# Summarising blog  27
# Summarising blog  28
# Summarising blog  29
# Summarising blog  30
# Summarising blog  31
# Summarising blog  32
# Summarising blog  33
# Summarising blog  34
# Summarising blog  35
# Summarising blog  36
# Summarising blog  37
# Summarising blog  38
# Summarising blog  39
# Summarising blog  40
# Summarising blog  41
# Summarising blog  42
# Summarising blog  43
# Summarising blog  44
# Summarising blog  45
# Summarising blog  46
# Summarising blog  47
# Summarising blog  48
# Summarising blog  49
# Summarising blog  50
# Summarising blog  51
# Summarising blog  52
# Summarising blog  53
# Summarising blog  54
# Summarising blog  55
# Summarising blog  56
# Summarising blog  57
# Summarising blog  58
# Summarising blog  59
# Summarising blog  60
# Summarising blog  61
# Summarising blog  62
# Summarising blog  63
# Summarising blog  64
# Summarising blog  65
# Summarising blog  66
# Summarising blog  67
# Summarising blog  68
# Summarising blog  69
# Summarising blog  70
# Summarising blog  71
# Summarising blog  72
# Summarising blog  73
# Summarising blog  74
# Summarising blog  75
# Summarising blog  76
# Summarising blog  77
# Summarising blog  78
# Summarising blog  79
# Summarising blog  80
# Summarising blog  81
# Summarising blog  82
# Summarising blog  83
# Summarising blog  84
# Summarising blog  85
# Summarising blog  86
# Summarising blog  87
# Summarising blog  88
# Summarising blog  89
# Summarising blog  90
# Summarising blog  91
# Summarising blog  92
# Summarising blog  93
# Summarising blog  94
# Summarising blog  95
# Summarising blog  96
# Summarising blog  97
# Summarising blog  98
# Summarising blog  99
# Summarising blog  100
# Summarising blog  101
# Summarising blog  102
# Summarising blog  103
# Summarising blog  104
# Summarising blog  105
# Summarising blog  106
# Summarising blog  107
# Summarising blog  108
# Summarising blog  109
# Summarising blog  110
# Summarising blog  111
# Summarising blog  112
# Summarising blog  113
# Summarising blog  114
# Summarising blog  115
# Summarising blog  116
# Summarising blog  117
# Summarising blog  118
# Summarising blog  119
# Summarising blog  120
# Summarising blog  121
# Summarising blog  122
# Summarising blog  123
# Summarising blog  124
# Summarising blog  125
# Summarising blog  126
# Summarising blog  127
# /usr/local/lib/python3.10/dist-packages/scipy/spatial/distance.py:647: RuntimeWarning: invalid value encountered in scalar divide
#   dist = 1.0 - uv / math.sqrt(uu * vv)
# Summarising blog  128
# Summarising blog  129
# Summarising blog  130
# Summarising blog  131
# Summarising blog  132
# Summarising blog  133
# Summarising blog  134
# Summarising blog  135
# Summarising blog  136
# Summarising blog  137
# Summarising blog  138
# Summarising blog  139
# Summarising blog  140
# Summarising blog  141
# Summarising blog  142
# Summarising blog  143
# Summarising blog  144
# Summarising blog  145
# Summarising blog  146
# Summarising blog  147
# Summarising blog  148
# Summarising blog  149
# Summarising blog  150
# Summarising blog  151
# Summarising blog  152
# Summarising blog  153
# Summarising blog  154
# Summarising blog  155
# Summarising blog  156
# Summarising blog  157
# Summarising blog  158
# Summarising blog  159
# Summarising blog  160
# Summarising blog  161
# Summarising blog  162
# Summarising blog  163
# Summarising blog  164
# Summarising blog  165
# Summarising blog  166
# Summarising blog  167
# Summarising blog  168
# Summarising blog  169
# Summarising blog  170
# Summarising blog  171
# Summarising blog  172
# Summarising blog  173
# Summarising blog  174
# Summarising blog  175
# Summarising blog  176
# Summarising blog  177
# Summarising blog  178
# Summarising blog  179
# Summarising blog  180
# Summarising blog  181
# Summarising blog  182
# Summarising blog  183
# Summarising blog  184
# Summarising blog  185
# Summarising blog  186
# Summarising blog  187
# Summarising blog  188
# Summarising blog  189
# Summarising blog  190
# Summarising blog  191
# Summarising blog  192
# Summarising blog  193
# Summarising blog  194
# Summarising blog  195
# Summarising blog  196
# Summarising blog  197
# Summarising blog  198
# Summarising blog  199
# Summarising blog  200
# Summarising blog  201
# Summarising blog  202
# Summarising blog  203
# Summarising blog  204
# Summarising blog  205
# Summarising blog  206
# Summarising blog  207
# Summarising blog  208
# Summarising blog  209
# Summarising blog  210
# Summarising blog  211
# Summarising blog  212
# Summarising blog  213
# Summarising blog  214
# Summarising blog  215
# Summarising blog  216
# Summarising blog  217
# Summarising blog  218
# Summarising blog  219
# Summarising blog  220
# Summarising blog  221
# Summarising blog  222
# Summarising blog  223
# Summarising blog  224
# Summarising blog  225
# Summarising blog  226
# Summarising blog  227
# Summarising blog  228
# Summarising blog  229
# Summarising blog  230
# Summarising blog  231
# Summarising blog  232
# Summarising blog  233
# Summarising blog  234
# Summarising blog  235
# Summarising blog  236
# Summarising blog  237
# Summarising blog  238
# Summarising blog  239
# Summarising blog  240
# Summarising blog  241
# Summarising blog  242
# Summarising blog  243
# Summarising blog  244
# Summarising blog  245
# Summarising blog  246
# Summarising blog  247
# Summarising blog  248
# Summarising blog  249
# Summarising blog  250
# Summarising blog  251
# Summarising blog  252
# Summarising blog  253
# Summarising blog  254
# Summarising blog  255
# Summarising blog  256
# Summarising blog  257
# Summarising blog  258
# Summarising blog  259
# Summarising blog  260
# Summarising blog  261
# Summarising blog  262
# Summarising blog  263
# Summarising blog  264
# Summarising blog  265
# Summarising blog  266
# Summarising blog  267
# Summarising blog  268
# Summarising blog  269
# Summarising blog  270
# Summarising blog  271
# Summarising blog  272
# Summarising blog  273
# Summarising blog  274
# Summarising blog  275
# Summarising blog  276
# Summarising blog  277
# Summarising blog  278
# Summarising blog  279
# Summarising blog  280
# Summarising blog  281
# Summarising blog  282
# Summarising blog  283
# Summarising blog  284
# Summarising blog  285
# Summarising blog  286
# Summarising blog  287
# Summarising blog  288
# Summarising blog  289
# Summarising blog  290
# Summarising blog  291
# Summarising blog  292
# Summarising blog  293
# Summarising blog  294
# Summarising blog  295
# Summarising blog  296
# Summarising blog  297
# Summarising blog  298
# Summarising blog  299
# Summarising blog  300
# Summarising blog  301
# Summarising blog  302
# Summarising blog  303
# Summarising blog  304
# Summarising blog  305
# Summarising blog  306
# Summarising blog  307
# Summarising blog  308
# Summarising blog  309
# Summarising blog  310
# Summarising blog  311
# Summarising blog  312
# Summarising blog  313
# Summarising blog  314
# Summarising blog  315
# Summarising blog  316
# Summarising blog  317
# Summarising blog  318
# Summarising blog  319
# Summarising blog  320
# Summarising blog  321
# Summarising blog  322
# Summarising blog  323
# Summarising blog  324
# Summarising blog  325
# Summarising blog  326
# Summarising blog  327
# Summarising blog  328
# Summarising blog  329
# Summarising blog  330
# Summarising blog  331
# Summarising blog  332
# Summarising blog  333
# Summarising blog  334
# Summarising blog  335
# Summarising blog  336
# Summarising blog  337
# Summarising blog  338
# Summarising blog  339
# Summarising blog  340
# Summarising blog  341
# Summarising blog  342
# Summarising blog  343
# Summarising blog  344
# Summarising blog  345
# Summarising blog  346
# Summarising blog  347
# Summarising blog  348
# Summarising blog  349
# Summarising blog  350
# Summarising blog  351
# Summarising blog  352
# Summarising blog  353
# Summarising blog  354
# Summarising blog  355
# Summarising blog  356
# Summarising blog  357
# Summarising blog  358
# Summarising blog  359
# Summarising blog  360
# Summarising blog  361
# Summarising blog  362
# Summarising blog  363
# Summarising blog  364
# Summarising blog  365
# Summarising blog  366
# Summarising blog  367
# Summarising blog  368
# Summarising blog  369
# Summarising blog  370
# Summarising blog  371
# Summarising blog  372
# Summarising blog  373
# Summarising blog  374
# Summarising blog  375
# Summarising blog  376
# Summarising blog  377
# Summarising blog  378
# Summarising blog  379
# Summarising blog  380
# Summarising blog  381
# Summarising blog  382
# Summarising blog  383
# Summarising blog  384
# Summarising blog  385
# Summarising blog  386
# Summarising blog  387
# Summarising blog  388
# Summarising blog  389
# Summarising blog  390
# Summarising blog  391
# Summarising blog  392
# Summarising blog  393
# Summarising blog  394
# Summarising blog  395
# Summarising blog  396
# Summarising blog  397
# Summarising blog  398
# Summarising blog  399
# Summarising blog  400
# Summarising blog  401
# Summarising blog  402
# Summarising blog  403
# Summarising blog  404
# Summarising blog  405
# Summarising blog  406
# Summarising blog  407
# Summarising blog  408
# Summarising blog  409
# Summarising blog  410
# Summarising blog  411
# Summarising blog  412
# Summarising blog  413
# Summarising blog  414
# Summarising blog  415
# Summarising blog  416
# Summarising blog  417
# Summarising blog  418
# Summarising blog  419
# Summarising blog  420
# Summarising blog  421
# Summarising blog  422
# Summarising blog  423
# Summarising blog  424
# Summarising blog  425
# Summarising blog  426
# Summarising blog  427
# Summarising blog  428
# Summarising blog  429
# Summarising blog  430
# Summarising blog  431
# Summarising blog  432
# Summarising blog  433
# Summarising blog  434
# Summarising blog  435
# Summarising blog  436
# Summarising blog  437
# Summarising blog  438
# Summarising blog  439
# Summarising blog  440
# Summarising blog  441
# Summarising blog  442
# Summarising blog  443
# Summarising blog  444
# Summarising blog  445
# Summarising blog  446
# Summarising blog  447
# Summarising blog  448
# Summarising blog  449
# Summarising blog  450
# Summarising blog  451
# Summarising blog  452
# Summarising blog  453
# Summarising blog  454
# Summarising blog  455
# Summarising blog  456
# Summarising blog  457
# Summarising blog  458
# Summarising blog  459
# Summarising blog  460
# Summarising blog  461
# Summarising blog  462
# Summarising blog  463
# Summarising blog  464
# Summarising blog  465
# Summarising blog  466
# Summarising blog  467
# Summarising blog  468
# Summarising blog  469
# Summarising blog  470
# Summarising blog  471
# Summarising blog  472
# Summarising blog  473
# Summarising blog  474
# Summarising blog  475
# Summarising blog  476
# Summarising blog  477
# Summarising blog  478
# Summarising blog  479
# Summarising blog  480
# Summarising blog  481
# Summarising blog  482
# Summarising blog  483
# Summarising blog  484
# Summarising blog  485
# Summarising blog  486
# Summarising blog  487
# Summarising blog  488
# Summarising blog  489
# Summarising blog  490
# Summarising blog  491
# Summarising blog  492
# Summarising blog  493
# Summarising blog  494
# Summarising blog  495
# Summarising blog  496
# Summarising blog  497
# Summarising blog  498
# Summarising blog  499
# Summarising blog  500
# Summarising blog  501
# Summarising blog  502
# Summarising blog  503
# Summarising blog  504
# Summarising blog  505
# Summarising blog  506
# Summarising blog  507
# Summarising blog  508
# Summarising blog  509
# Summarising blog  510
# Summarising blog  511
# Summarising blog  512
# Summarising blog  513
# Summarising blog  514
# Summarising blog  515
# Summarising blog  516
# Summarising blog  517
# Summarising blog  518
# Summarising blog  519
# Summarising blog  520
# Summarising blog  521
# Summarising blog  522
# Summarising blog  523
# Summarising blog  524
# Summarising blog  525
# Summarising blog  526
# Summarising blog  527
# Summarising blog  528
# Summarising blog  529
# Summarising blog  530
# Summarising blog  531
# Summarising blog  532
# Summarising blog  533
# Summarising blog  534
# Summarising blog  535
# Summarising blog  536
# Summarising blog  537
# Summarising blog  538
# Summarising blog  539
# Summarising blog  540
# Summarising blog  541
# Summarising blog  542
# Summarising blog  543
# Summarising blog  544
# Summarising blog  545
# Summarising blog  546
# Summarising blog  547
# Summarising blog  548
# Summarising blog  549
# Summarising blog  550
# Summarising blog  551
# Summarising blog  552
# Summarising blog  553
# Summarising blog  554
# Summarising blog  555
# Summarising blog  556
# Summarising blog  557
# Summarising blog  558
# Summarising blog  559
# Summarising blog  560
# Summarising blog  561
# Summarising blog  562
# Summarising blog  563
# Summarising blog  564
# Summarising blog  565
# Summarising blog  566
# Summarising blog  567
# Summarising blog  568
# Summarising blog  569
# Summarising blog  570
# Summarising blog  571
# Summarising blog  572
# Summarising blog  573
# Summarising blog  574
# Summarising blog  575
# Summarising blog  576
# Summarising blog  577
# Summarising blog  578
# Summarising blog  579
# Summarising blog  580
# Summarising blog  581
# Summarising blog  582
# Summarising blog  583
# Summarising blog  584
# Summarising blog  585
# Summarising blog  586
# Summarising blog  587
# Summarising blog  588
# Summarising blog  589
# Summarising blog  590
# Summarising blog  591
# Summarising blog  592
# Summarising blog  593
# Summarising blog  594
# Summarising blog  595
# Summarising blog  596
# Summarising blog  597
# Summarising blog  598
# Summarising blog  599
# Summarising blog  600
# Summarising blog  601
# Summarising blog  602
# Summarising blog  603
# Summarising blog  604
# Summarising blog  605
# Summarising blog  606
# Summarising blog  607
# Summarising blog  608
# Summarising blog  609
# Summarising blog  610
# Summarising blog  611
# Summarising blog  612
# Summarising blog  613
# Summarising blog  614
# Summarising blog  615
# Summarising blog  616
# Summarising blog  617
# Summarising blog  618
# Summarising blog  619
# Summarising blog  620
# Summarising blog  621
# Summarising blog  622
# Summarising blog  623
# Summarising blog  624
# Summarising blog  625
# Summarising blog  626
# Summarising blog  627
# Summarising blog  628
# Summarising blog  629
# Summarising blog  630
# Summarising blog  631
# Summarising blog  632
# Summarising blog  633
# Summarising blog  634
# Summarising blog  635
# Summarising blog  636
# Summarising blog  637
# Summarising blog  638
# Summarising blog  639
# Summarising blog  640
# Summarising blog  641
# Summarising blog  642
# Summarising blog  643
# Summarising blog  644
# Summarising blog  645
# Summarising blog  646
# Summarising blog  647
# Summarising blog  648
# Summarising blog  649
# Summarising blog  650
# Summarising blog  651
# Summarising blog  652
# Summarising blog  653
# Summarising blog  654
# Summarising blog  655
# Summarising blog  656
# Summarising blog  657
# Summarising blog  658
# Summarising blog  659
# Summarising blog  660
# Summarising blog  661
# Summarising blog  662
# Summarising blog  663
# Summarising blog  664
# Summarising blog  665
# Summarising blog  666
# Summarising blog  667
# Summarising blog  668
# Summarising blog  669
# Summarising blog  670
# Summarising blog  671
# Summarising blog  672
# Summarising blog  673
# Summarising blog  674
# Summarising blog  675
# Summarising blog  676
# Summarising blog  677
# Summarising blog  678
# Summarising blog  679
# Summarising blog  680
# Summarising blog  681
# Summarising blog  682
# Summarising blog  683
# Summarising blog  684
# Summarising blog  685
# Summarising blog  686
# Summarising blog  687
# Summarising blog  688
# Summarising blog  689
# Summarising blog  690
# Summarising blog  691
# Summarising blog  692
# Summarising blog  693
# Summarising blog  694
# Summarising blog  695
# Summarising blog  696
# Summarising blog  697
# Summarising blog  698
# Summarising blog  699
# Summarising blog  700
# Summarising blog  701
# Summarising blog  702
# Summarising blog  703
# Summarising blog  704
# Summarising blog  705
# Summarising blog  706
# Summarising blog  707
# Summarising blog  708
# Summarising blog  709
# Summarising blog  710
# Summarising blog  711
# Summarising blog  712
# Summarising blog  713
# Summarising blog  714
# Summarising blog  715
# Summarising blog  716
# Summarising blog  717
# Summarising blog  718
# Summarising blog  719
# Summarising blog  720
# Summarising blog  721
# Summarising blog  722
# Summarising blog  723
# Summarising blog  724
# Summarising blog  725
# Summarising blog  726
# Summarising blog  727
# Summarising blog  728
# Summarising blog  729
# Summarising blog  730
# Summarising blog  731
# Summarising blog  732
# Summarising blog  733
# Summarising blog  734
# Summarising blog  735
# Summarising blog  736
# Summarising blog  737
# Summarising blog  738
# Summarising blog  739
# Summarising blog  740
# Summarising blog  741
# Summarising blog  742
# Summarising blog  743
# Summarising blog  744
# Summarising blog  745
# Summarising blog  746
# Summarising blog  747
# Summarising blog  748
# Summarising blog  749
# Summarising blog  750
# Summarising blog  751
# Summarising blog  752
# Summarising blog  753
# Summarising blog  754
# Summarising blog  755
# Summarising blog  756
# Summarising blog  757
# Summarising blog  758
# Summarising blog  759
# Summarising blog  760
# Summarising blog  761
# Summarising blog  762
# Summarising blog  763
# Summarising blog  764
# Summarising blog  765
# Summarising blog  766
# Summarising blog  767
# Summarising blog  768
# Summarising blog  769
# Summarising blog  770
# Summarising blog  771
# Summarising blog  772
# Summarising blog  773
# Summarising blog  774
# Summarising blog  775
# Summarising blog  776
# Summarising blog  777
# Summarising blog  778
# Summarising blog  779
# Summarising blog  780
# Summarising blog  781
# Summarising blog  782
# Summarising blog  783
# Summarising blog  784
# Summarising blog  785
# Summarising blog  786
# Summarising blog  787
# Summarising blog  788
# Summarising blog  789
# Summarising blog  790
# Summarising blog  791
# Summarising blog  792
# Summarising blog  793
# Summarising blog  794
# Summarising blog  795
# Summarising blog  796
# Summarising blog  797
# Summarising blog  798
# Summarising blog  799
# Summarising blog  800
# Summarising blog  801
# Summarising blog  802
# Summarising blog  803
# Summarising blog  804
# Summarising blog  805
# Summarising blog  806
# Summarising blog  807
# Summarising blog  808
# Summarising blog  809
# Summarising blog  810
# Summarising blog  811
# Summarising blog  812
# Summarising blog  813
# Summarising blog  814
# Summarising blog  815
# Summarising blog  816
# Summarising blog  817
# Summarising blog  818
# Summarising blog  819
# Summarising blog  820
# Summarising blog  821
# Summarising blog  822
# Summarising blog  823
# Summarising blog  824
# Summarising blog  825
# Summarising blog  826
# Summarising blog  827
# Summarising blog  828
# Summarising blog  829
# Summarising blog  830
# Summarising blog  831
# Summarising blog  832
# Summarising blog  833
# Summarising blog  834
# Summarising blog  835
# Summarising blog  836
# Summarising blog  837
# Summarising blog  838
# Summarising blog  839
# Summarising blog  840
# Summarising blog  841
# Summarising blog  842
# Summarising blog  843
# Summarising blog  844
# Summarising blog  845
# Summarising blog  846
# Summarising blog  847
# Summarising blog  848
# Summarising blog  849
# Summarising blog  850
# Summarising blog  851
# Summarising blog  852
# Summarising blog  853
# Summarising blog  854
# Summarising blog  855
# Summarising blog  856
# Summarising blog  857
# Summarising blog  858
# Summarising blog  859
# Summarising blog  860
# Summarising blog  861
# Summarising blog  862
# Summarising blog  863
# Summarising blog  864
# Summarising blog  865
# Summarising blog  866
# Summarising blog  867
# Summarising blog  868
# Summarising blog  869
# Summarising blog  870
# Summarising blog  871
# Summarising blog  872
# Summarising blog  873
# Summarising blog  874
# Summarising blog  875
# Summarising blog  876
# Summarising blog  877
# Summarising blog  878
# Summarising blog  879
# Summarising blog  880
# Summarising blog  881
# Summarising blog  882
# Summarising blog  883
# Summarising blog  884
